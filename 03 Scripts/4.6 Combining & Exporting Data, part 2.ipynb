# %% [markdown]
# ## Merging and Exporting Data
# ## This script includes the following points:
# ## Step 3. Import the data.
# ## Step 4. Check the Output of Dataframes.
# ## Step 5. Merge df_prods with df_ords_combined.
# ## Step 6. Confirm the results of the merge using the merge flag.
# ## Step 7. Export the file.

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Step 3. Import the data.

# %%
#Import Data
path = r'C:\Users\Raghu\Instacart Basket Analysis\02 Data\Prepared Data/prods_checked.csv'

# %%
path = r'C:\Users\Raghu\Instacart Basket Analysis\02 Data\Prepared Data/orders_checked.csv'

# %%
path = r'C:\Users\Raghu\Instacart Basket Analysis\02 Data\Prepared Data/orders_products_combined.csv'

# %%
path = r'C:\Users\Raghu\Instacart Basket Analysis\02 Data\Prepared Data/orders_products_combined.pkl'

# %%
df_prods = pd.read_csv(os.path.join(r'C:\Users\Raghu\Instacart Basket Analysis\02 Data\Prepared Data/prods_checked.csv'), index_col = False)

# %%
path = 'C:\\Users\\Raghu\\Instacart Basket Analysis\\'

# %%
df_ords_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # Step 4. Check the Output of Dataframes.

# %%
#Check Output: df_prods
df_prods.head()
# Out:
#    order_id  user_id  order_number  order_of_week  oder_hour_of _day  \
# 0   2539329        1             1              2                  8
# 1   2398795        1             2              3                  7
# 2    473747        1             3              3                 12
# 3   2254736        1             4              4                  7
# 4    431534        1             5              4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_prods.describe()
# Out:
#            order_id       user_id  order_number  order_of_week  \
# count  1.048575e+06  1.048575e+06  1.048575e+06   1.048575e+06
# mean   1.710968e+06  3.156404e+04  1.717418e+01   2.778637e+00
# std    9.875774e+05  1.816695e+04  1.771094e+01   2.047751e+00
# min    6.000000e+00  1.000000e+00  1.000000e+00   0.000000e+00
# 25%    8.554670e+05  1.589600e+04  5.000000e+00   1.000000e+00
# 50%    1.710657e+06  3.160800e+04  1.100000e+01   3.000000e+00
# 75%    2.566970e+06  4.729700e+04  2.300000e+01   5.000000e+00
# max    3.421083e+06  6.310000e+04  1.000000e+02   6.000000e+00
#
#        oder_hour_of _day  days_since_prior_order
# count       1.048575e+06           985475.000000
# mean        1.345229e+01               11.102506
# std         4.219144e+00                9.186663
# min         0.000000e+00                0.000000
# 25%         1.000000e+01                4.000000
# 50%         1.300000e+01                7.000000
# 75%         1.600000e+01               15.000000
# ...

# %%
df_prods.shape
# Out:
# (1048575, 6)

# %%
#Check Output: df_ords_combined
df_ords_combined.head()
# Out:
#    order_id  user_id  order_number  order_of_week  oder_hour_of _day  \
# 0   2539329        1             1              2                  8
# 1   2539329        1             1              2                  8
# 2   2539329        1             1              2                  8
# 3   2539329        1             1              2                  8
# 4   2539329        1             1              2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_ords_combined.shape
# Out:
# (9927471, 10)

# %% [markdown]
# ## Step 5. Merge df_prods with df_ords_combined

# %% [markdown]
# defining the prods

# %%
import pandas as pd
df_prods = pd.read_csv(r'C:\Users\Raghu\Instacart Basket Analysis\02 Data\Prepared Data\prods_checked.csv')

# %%
file_path_prods = r'C:\Users\Raghu\Instacart Basket Analysis\02 Data\Prepared Data\prods_checked.csv'

# %%
#Drop unnamed columns in df_prods

df_prods = df_prods.drop(columns=['Unnamed: 0'], errors='ignore')

# %%
file_path_ords_combined = r'C:\Users\Raghu\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.csv'

# %%
df_ords_combined = pd.read_csv(file_path_ords_combined)

# %%
#Drop unnamed columns in df_ords_combined
df_ords_combined = df_ords_combined.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', '_merge'], errors='ignore')

# %% [markdown]
# ##Merge df_prods and df_ords_combined

# %%
import pandas as pd

# %%
orders_products_combined_path = r'C:\Users\Raghu\Instacart Basket Analysis\01 Project Management\02 Data\03 Scripts\prepared data\orders_products_combined.csv'

# %%
products_prepared_path = r'C:\Users\Raghu\Instacart Basket Analysis\01 Project Management\02 Data\03 Scripts\prepared data\orders_products_combined.csv'

# %%
products_prepared = pd.read_csv(products_prepared_path)

# %%
orders_products_combined = pd.read_csv(r'C:\Users\Raghu\Instacart Basket Analysis\01 Project Management\02 Data\03 Scripts\prepared data\orders_products_combined.csv'
)

# %%
products_prepared = pd.read_csv(r'C:\Users\Raghu\Instacart Basket Analysis\01 Project Management\02 Data\03 Scripts\prepared data\prods_data.csv')

# %%
df_combined = pd.merge(orders_products_combined, products_prepared, on='product_id')

# %%
df_prods = pd.read_csv(r'C:\Users\Raghu\Instacart Basket Analysis\01 Project Management\02 Data\03 Scripts\prepared data\prods_data.csv')

# %%
df_ords_combined = pd.read_csv(r'C:\Users\Raghu\Instacart Basket Analysis\01 Project Management\02 Data\03 Scripts\prepared data\orders_products_combined.csv')

# %%
df_merged = df_prods.merge(df_ords_combined, on='product_id', indicator='merge_indicator')

# %%
df_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    Unnamed: 0  order_id  user_id  order_number  order_of_week  \
# 0       16802   3139998      138            28              6
# 1       16806   1977647      138            30              6
# 2      106710    389851      709             2              0
# 3      113536    652770      764             1              3
# 4      113575   1813452      764             3              4
#
#    oder_hour_of _day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %% [markdown]
# ## Step 6. Confirm the results of the merge using the merge flag.

# %%
df_merged
# Out:
#          product_id                                product_name  aisle_id  \
# 0                 1                  Chocolate Sandwich Cookies        61
# 1                 1                  Chocolate Sandwich Cookies        61
# 2                 1                  Chocolate Sandwich Cookies        61
# 3                 1                  Chocolate Sandwich Cookies        61
# 4                 1                  Chocolate Sandwich Cookies        61
# ...             ...                                         ...       ...
# 1048581       49683                              Cucumber Kirby        83
# 1048582       49683                              Cucumber Kirby        83
# 1048583       49683                              Cucumber Kirby        83
# 1048584       49687  Smartblend Healthy Metabolism Dry Cat Food        41
# 1048585       49687  Smartblend Healthy Metabolism Dry Cat Food        41
#
#          department_id  prices  Unnamed: 0  order_id  user_id  order_number  \
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both    1048586
# Name: count, dtype: int64

# %% [markdown]
# ## Step 7. Export the File.

# %%
#Export orders_products_merged file
import os
import pandas as pd

# %%
path = r'C:\\Users\\Raghu\\Instacart Basket Analysis\\01 Project Management\\02 Data\\03 Scripts\\Prepared Data'

# %%
os.makedirs(os.path.join(path, '02 Data', '03 Scripts', 'Prepared Data'), exist_ok=True)

# %%
df_merged.to_pickle(os.path.join(path, '02 Data', '03 Scripts', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_merged.to_csv(os.path.join(path, '02 Data', '03 Scripts', 'Prepared Data', 'orders_products_merged.csv'))
