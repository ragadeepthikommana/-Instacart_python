# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#Import Data
path = r'C:\Users\Raghu\Instacart Basket Analysis\01 Project Management\02 Data\03 Scripts\prepared data\orders_products_merged.csv'

# %%
ords_prods_merge = pd.read_csv(r'C:\Users\Raghu\Instacart Basket Analysis\01 Project Management\02 Data\03 Scripts\prepared data\orders_products_merged.csv')

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head()
# Out:
#    Unnamed: 0.1  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             1           1  Chocolate Sandwich Cookies        61
# 2             2           1  Chocolate Sandwich Cookies        61
# 3             3           1  Chocolate Sandwich Cookies        61
# 4             4           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0  order_id  user_id  order_number  \
# 0             19     5.8       16802   3139998      138            28
# 1             19     5.8       16806   1977647      138            30
# 2             19     5.8      106710    389851      709             2
# 3             19     5.8      113536    652770      764             1
# 4             19     5.8      113575   1813452      764             3
#
#    order_of_week  oder_hour_of _day  days_since_prior_order  \
# 0              6                 11                     3.0
# ...

# %%
df.groupby('product_name')

# %% [markdown]
# #Aggregating Data with agg()

# %%
#Performing a Single Aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.863250
# 2                17.159292
# 3                17.941852
# 4                17.960111
# 5                14.449350
# 6                15.434486
# 7                17.834437
# 8                16.390612
# 9                15.970112
# 10               20.150624
# 11               16.507116
# 12               15.672342
# 13               16.517841
# 14               17.542775
# 15               15.824112
# 16               17.984989
# 17               16.366399
# 18               19.433633
# 19               17.720621
# 20               17.355923
# 21               21.810965

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.863250
# 2     17.159292
# 3     17.941852
# 4     17.960111
# 5     14.449350
# 6     15.434486
# 7     17.834437
# 8     16.390612
# 9     15.970112
# 10    20.150624
# 11    16.507116
# 12    15.672342
# 13    16.517841
# 14    17.542775
# 15    15.824112
# 16    17.984989
# 17    16.366399
# 18    19.433633
# 19    17.720621
# 20    17.355923
# 21    21.810965
# Name: order_number, dtype: float64

# %%
#DOT NOTATION VS. SQUARE BRACKETS

df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 1     14.863250
# 2     17.159292
# 3     17.941852
# 4     17.960111
# 5     14.449350
# 6     15.434486
# 7     17.834437
# 8     16.390612
# 9     15.970112
# 10    20.150624
# 11    16.507116
# 12    15.672342
# 13    16.517841
# 14    17.542775
# 15    15.824112
# 16    17.984989
# 17    16.366399
# 18    19.433633
# 19    17.720621
# 20    17.355923
# 21    21.810965
# Name: order_number, dtype: float64

# %%
#Performing Multiple Aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.863250   1  99
# 2                17.159292   1  98
# 3                17.941852   1  99
# 4                17.960111   1  99
# 5                14.449350   1  99
# 6                15.434486   1  99
# 7                17.834437   1  99
# 8                16.390612   1  91
# 9                15.970112   1  99
# 10               20.150624   1  99
# 11               16.507116   1  99
# 12               15.672342   1  99
# 13               16.517841   1  99
# 14               17.542775   1  99
# 15               15.824112   1  99
# 16               17.984989   1  99
# 17               16.366399   1  99
# 18               19.433633   1  99
# 19               17.720621   1  99
# 20               17.355923   1  99
# 21               21.810965   1  97

# %%
#Aggregating Data with transform()
create a loyality flag using loc
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              1           1  Chocolate Sandwich Cookies        61
# 2              2           1  Chocolate Sandwich Cookies        61
# 3              3           1  Chocolate Sandwich Cookies        61
# 4              4           1  Chocolate Sandwich Cookies        61
# 5              5           1  Chocolate Sandwich Cookies        61
# 6              6           1  Chocolate Sandwich Cookies        61
# 7              7           1  Chocolate Sandwich Cookies        61
# 8              8           1  Chocolate Sandwich Cookies        61
# 9              9           1  Chocolate Sandwich Cookies        61
# 10            10           1  Chocolate Sandwich Cookies        61
# 11            11           1  Chocolate Sandwich Cookies        61
# 12            12           1  Chocolate Sandwich Cookies        61
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  product_id                                    product_name  \
# 0              0           1                      Chocolate Sandwich Cookies
# 1              1           1                      Chocolate Sandwich Cookies
# 2              2           1                      Chocolate Sandwich Cookies
# 3              3           1                      Chocolate Sandwich Cookies
# 4              4           1                      Chocolate Sandwich Cookies
# ..           ...         ...                                             ...
# 95            95          10  Sparkling Orange Juice & Prickly Pear Beverage
# 96            96          10  Sparkling Orange Juice & Prickly Pear Beverage
# 97            97          10  Sparkling Orange Juice & Prickly Pear Beverage
# 98            98          10  Sparkling Orange Juice & Prickly Pear Beverage
# 99            99          10  Sparkling Orange Juice & Prickly Pear Beverage
#
# ...

# %%
pd.options.display.max_rows = None

# %% [markdown]
# #Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    503996
# Loyal customer      341149
# New customer        203441
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...
